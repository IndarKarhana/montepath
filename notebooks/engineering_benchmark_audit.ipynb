# %% [markdown]
# # Engineering Benchmark Audit
#
# Run compact benchmark checks and inspect methodology metadata.

# %%
from montepath import recommend_method, run_benchmarks

print(recommend_method(workload_family="arithmetic_asian_call", n_paths=100_000, n_steps=64, prefer_accuracy=True))

for row in run_benchmarks(profile="compact", release=False):
    if row.metric_name:
        print(row.benchmark_name, row.methodology, row.metric_name, row.metric_value)
